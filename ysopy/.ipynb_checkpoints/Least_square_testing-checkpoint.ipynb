# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import least_squares
import astropy.units as u
import astropy.constants as const
# %matplotlib inline

# %%
x_train = np.linspace(-5, 5, 100)
def gen_data(t, a, b, c, mu=0, sigma=0):
    y = a*(t**2) + b*t + c
    noise = np.random.normal(mu, sigma, len(t))
    y_train = y + noise
    return y_train
y_train = gen_data(x_train, 10, 10, 0, mu=0, sigma=10)
plt.plot(x_train, y_train)

# %%
def fun(x, t, y):
    """
        x[0] = a
        x[1] = b
        x[2] = c
        y = a*(x**2) + b*x + c
    """
    return x[0]*t**2 + x[1]*t + x[2] - y

# %%
x0 = [-900, 5, 1]
res_lsq = least_squares(fun, x0, args=(x_train, y_train))
res_lsq
# Out:
#      message: `ftol` termination condition is satisfied.
#      success: True
#       status: 2
#          fun: [ 3.262e+00 -4.529e+00 ...  1.508e+01 -2.852e+00]
#            x: [ 9.960e+00  1.017e+01 -1.798e-01]
#         cost: 4904.803406951835
#          jac: [[ 2.500e+01 -5.000e+00  1.000e+00]
#                [ 2.400e+01 -4.899e+00  1.000e+00]
#                ...
#                [ 2.400e+01  4.899e+00  1.000e+00]
#                [ 2.500e+01  5.000e+00  1.000e+00]]
#         grad: [ 1.297e-05 -8.882e-06  2.842e-14]
#   optimality: 1.2968594205631234e-05
#  active_mask: [ 0.000e+00  0.000e+00  0.000e+00]
#         nfev: 4
#         njev: 4

# %%
y_lsq = gen_data(x_train, *res_lsq.x)

# %%
plt.plot(x_train, y_train)
plt.plot(x_train, y_lsq)

# %%
from ysopy import base_funcs as bf
dict_config = bf.config_read("config_file.cfg")
dict_config
# Out:
# {'b': <Quantity 1. kG>,
#  'm': <Quantity 1.39188691e+30 kg>,
#  'm_dot': <Quantity 2.52035626e+16 kg / s>,
#  'r_star': <Quantity 1.18269e+09 m>,
#  'log_g_star': 3.5,
#  'inclination': <Quantity 38. deg>,
#  'd_star': <Quantity 3.08567758e+17 m>,
#  't_star': <Quantity 4600. K>,
#  't_0': <Quantity 4600. K>,
#  'av': 10.0,
#  'rv': 3.1,
#  'l_0': <Quantity 3000. Angstrom>,
#  'l_l_slab': <Quantity 3000. Angstrom>,
#  'mag_comp': 'hslab',
#  't_slab': <Quantity 8500. K>,
#  'n_e': <Quantity 1.e+13 1 / cm3>,
#  'tau': 1.0,
#  'save': False,
#  'plot': False,
#  'save_grid_data': False,
#  'save_each': False,
#  'l_min': <Quantity 1250. Angstrom>,
#  'l_max': <Quantity 50000. Angstrom>,
#  'n_data': 420000,
#  'n_disk': 500,
#  'n_dust_disk': 2000,
#  'n_h_minus': 5000,
#  'n_h': 150,
#  'bt_settl_path': '/home/arch/yso/trial_downloads',
#  'save_loc': '/home/arch/yso/trial_25_03/save',
#  'h_grid_path': '/home/arch/yso/H_slab_data/GridHslab',
#  'h_min_grid_path': '/home/arch/yso/H_slab_data/GridH-slab'}

# %%
r_train = np.load("radius_arr.npy")
temp_train = np.load("temp_arr.npy")
plt.plot(r_train, temp_train)
plt.show()

# %%
print(f" B: {dict_config['b']} \n m: {dict_config['m']} \n m_dot: {dict_config['m_dot']} \n R: {dict_config['r_star']}")
# Out:
#  B: 1.0 kG
#  m: 1.3918869094886355e+30 kg
#  m_dot: 2.520356263718471e+16 kg / s
#  R: 1182690000.0 m

# %%
print(dict_config['m']*dict_config['m_dot'])
# Out:
# 3.508050890717427e+46 kg2 / s

# %%
def temp_visc(config: dict, r, r_in):
    """Define the temperature profile for the viscously heated disk

    Parameters
    ----------
    config : dict
        dictionary containing system parameters

    r : astropy.units.Quantity
        value of the radius at which the temperature is to be calculated

    r_in : astropy.units.Quantity
        inner truncation radius of the viscously heated disk

    Returns
    ----------
    t : astropy.units.Quantity
        temperature at the given radius
    """
    m = config['m']
    m_dot = config['m_dot']
    if r > 49 / 36 * r_in:
        t = ((3 * const.G * m * m_dot) * (1 - np.sqrt(r_in / r)) / (8 * np.pi * const.sigma_sb * r ** 3)) ** 0.25
    else:
        # just give max temp
        t = ((3 * const.G * m * m_dot) * (1 / 7) / (8 * np.pi * const.sigma_sb * (49 / 36 * r_in) ** 3)) ** 0.25
    return t.to(u.K)

# %%
# making a dummy cfg dict
dum_cfg = bf.config_read("config_file.cfg")

def fun2(x, t, y):
    """
    Error function for radial-temperature profile fitting
    x[0] = b
    x[1] = m
    x[2] = m_dot
    x[3] = r_star

    y = observed data
    
    Here the fitting is not so good because we are fixing the radius array, but in reality
    it also depends on the x vector parameters
    """
    dum_cfg["b"] = x[0] * u.kilogauss
    dum_cfg["m"] = x[1] * const.M_sun
    dum_cfg["m_dot"] = x[2] * const.M_sun/ (1 * u.year).to(u.s)
    dum_cfg["r_star"] = x[3] * const.R_sun
    
    ## Below part is copeied from generate visc temp func with some changes
    m = dum_cfg['m']
    r_star = dum_cfg['r_star']
    m_dot = dum_cfg['m_dot']
    n_disk = dum_cfg['n_disk']
    b = dum_cfg["b"]
    
    m_sun_yr = const.M_sun / (1 * u.yr).to(u.s)
    r_in = 7.186 * (b / (1 * u.kG)) ** (4 / 7) * (r_star / (2 * const.R_sun)) ** (5 / 7) / (
            (m_dot / (1e-8 * m_sun_yr)) ** (2 / 7) * (m / (0.5 * const.M_sun)) ** (1 / 7)) * r_star
    r_in = r_in / 2.0  # correction factor taken 0.5, ref Long, Romanova, Lovelace 2005
    print("R_in\t:\t", r_in)
    print("R_star\t:\t", r_star)
    r_in = max([r_in, r_star])

    # estimate R_sub
    r_sub_approx = ((3 * const.G * m * m_dot) / (8 * np.pi * const.sigma_sb * (1400 * u.K) ** 4)) ** (1 / 3)

    # r_visc = np.linspace(r_in, r_sub_approx, n_disk)
    r_visc = t * u.m
    
    t_visc = np.zeros(len(r_visc)) * u.K

    for i in range(len(t_visc)):
        t_visc[i] = temp_visc(dum_cfg, r_visc[i], r_in)
    return t_visc.si.value - y

# %%
x0 = [1, 1, 1e-8, 1]
res_lsq = least_squares(fun2, x0, args=(r_train, temp_train))
# Out:
# R_in	:	 1379918731.6318483 m
# R_star	:	 695700000.0 m
# R_in	:	 1379918743.381786 m
# R_star	:	 695700000.0 m
# R_in	:	 1379918728.6943636 m
# R_star	:	 695700000.0 m
# R_in	:	 1063280649.0437698 m
# R_star	:	 695700000.0 m
# R_in	:	 1379918766.8816624 m
# R_star	:	 695700010.3667378 m
# R_in	:	 2635180665.5387726 m
# R_star	:	 1494172144.1718178 m
# R_in	:	 2635180687.9772024 m
# R_star	:	 1494172144.1718178 m
# R_in	:	 2635180659.9291654 m
# R_star	:	 1494172144.1718178 m
# R_in	:	 2554882736.3327136 m
# R_star	:	 1494172144.1718178 m
# R_in	:	 2635180732.854062 m
# R_star	:	 1494172166.4367177 m
# R_in	:	 1020365429.6414217 m
# R_star	:	 1040124336.4264245 m
# R_in	:	 1020365438.3297815 m
# R_star	:	 1040124336.4264245 m
# R_in	:	 1020365426.4048717 m
# R_star	:	 1040124336.4264245 m
# R_in	:	 1010434688.1987575 m
# R_star	:	 1040124336.4264245 m
# R_in	:	 1020365455.7065012 m
# R_star	:	 1040124351.9254849 m
# /home/arch/anaconda3/envs/yso/lib/python3.10/site-packages/astropy/units/quantity.py:620: RuntimeWarning: invalid value encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# R_in	:	 nan m
# R_star	:	 1236681162.2700136 m
# R_in	:	 1072130964.6672616 m
# R_star	:	 1236681146.0894785 m
# R_in	:	 1072130973.7964023 m
# R_star	:	 1236681146.0894785 m
# R_in	:	 1072130958.0128299 m
# R_star	:	 1236681146.0894785 m
# R_in	:	 1068942678.6541682 m
# R_star	:	 1236681146.0894785 m
# R_in	:	 1072130992.0546837 m
# R_star	:	 1236681164.5174634 m
# R_in	:	 902624667.6692406 m
# R_star	:	 1166534764.9352708 m
# R_in	:	 902624675.3550438 m
# R_star	:	 1166534764.9352708 m
# R_in	:	 902624665.1545233 m
# R_star	:	 1166534764.9352708 m
# R_in	:	 899513943.9478123 m
# R_star	:	 1166534764.9352708 m
# R_in	:	 902624690.7266506 m
# R_star	:	 1166534782.3179934 m
# R_in	:	 nan m
# R_star	:	 1183886016.6887214 m
# R_in	:	 847208184.7218403 m
# R_star	:	 1183885997.008205 m
# R_in	:	 847208191.9357749 m
# R_star	:	 1183885997.008205 m
# R_in	:	 847208181.4369091 m
# R_star	:	 1183885997.008205 m
# R_in	:	 845388240.9433404 m
# R_star	:	 1183885997.008205 m
# R_in	:	 847208206.3636446 m
# R_star	:	 1183886014.649481 m
# R_in	:	 799099996.340115 m
# R_star	:	 1182638376.9754791 m
# R_in	:	 801626977.6057767 m
# R_star	:	 1182638374.956355 m
# R_in	:	 801626984.4315897 m
# R_star	:	 1182638374.956355 m
# R_in	:	 801626974.1578413 m
# R_star	:	 1182638374.956355 m
# R_in	:	 800269771.2666454 m
# R_star	:	 1182638374.956355 m
# R_in	:	 801626998.0832162 m
# R_star	:	 1182638392.5790403 m
# R_in	:	 826874746.8336093 m
# R_star	:	 1182690409.6852646 m
# R_in	:	 800851933.6853333 m
# R_star	:	 1182690412.3514855 m
# R_in	:	 800851940.5045468 m
# R_star	:	 1182690412.3514855 m
# R_in	:	 800851930.4193232 m
# R_star	:	 1182690412.3514855 m
# R_in	:	 799464656.7712767 m
# R_star	:	 1182690412.3514855 m
# R_in	:	 800851954.1429744 m
# R_star	:	 1182690429.9749463 m
# R_in	:	 181041352.94276702 m
# R_star	:	 1145035399.935399 m
# R_in	:	 278918274.2639511 m
# R_star	:	 1173276659.2474687 m
# R_in	:	 409814834.36677366 m
# R_star	:	 1180336974.075486 m
# R_in	:	 567572546.6907976 m
# R_star	:	 1182102052.7824903 m
# R_in	:	 702363320.626264 m
# R_star	:	 1182543322.4592414 m
# R_in	:	 770335066.3938043 m
# R_star	:	 1182653639.8784294 m
# R_in	:	 792710812.9733677 m
# R_star	:	 1182681219.2332265 m
# R_in	:	 798781394.2356551 m
# R_star	:	 1182688114.0719275 m
# R_in	:	 800332038.243359 m
# R_star	:	 1182689837.7816448 m
# R_in	:	 800332045.0581455 m
# R_star	:	 1182689837.7816448 m
# R_in	:	 800332034.9794691 m
# R_star	:	 1182689837.7816448 m
# R_in	:	 798948793.1421595 m
# R_star	:	 1182689837.7816448 m
# R_in	:	 800332058.6877191 m
# R_star	:	 1182689855.4050968 m
# R_in	:	 800914972.9354 m
# R_star	:	 1182690478.4752958 m
# R_in	:	 800462913.7320297 m
# R_star	:	 1182689981.6457279 m
# R_in	:	 800462920.5479307 m
# R_star	:	 1182689981.6457279 m
# R_in	:	 800462910.4676082 m
# R_star	:	 1182689981.6457279 m
# R_in	:	 799078654.063438 m
# R_star	:	 1182689981.6457279 m
# R_in	:	 800462934.1797332 m
# R_star	:	 1182689999.269182 m
# R_in	:	 800975075.3320153 m
# R_star	:	 1182690556.2160113 m
# R_in	:	 800590816.2654531 m
# R_star	:	 1182690125.288298 m
# R_in	:	 800494880.7577957 m
# R_star	:	 1182690017.5563676 m
# R_in	:	 800494887.573969 m
# R_star	:	 1182690017.5563676 m
# R_in	:	 800494877.4932439 m
# R_star	:	 1182690017.5563676 m
# R_in	:	 799110373.3089926 m
# R_star	:	 1182690017.5563676 m
# R_in	:	 800494901.2063156 m
# R_star	:	 1182690035.1798222 m
# R_in	:	 800433956.492043 m
# R_star	:	 1182689949.4356549 m
# R_in	:	 800479267.0369592 m
# R_star	:	 1182690000.0970101 m
# R_in	:	 800479273.8529994 m
# R_star	:	 1182690000.0970101 m
# R_in	:	 800479263.7724711 m
# R_star	:	 1182690000.0970101 m
# R_in	:	 799094880.6088715 m
# R_star	:	 1182690000.0970101 m
# R_in	:	 800479287.4850807 m
# R_star	:	 1182690017.7204647 m
# R_in	:	 800479226.5244577 m
# R_star	:	 1182690000.0001304 m
# R_in	:	 800479233.3404977 m
# R_star	:	 1182690000.0001304 m
# R_in	:	 800479223.2599702 m
# R_star	:	 1182690000.0001304 m
# R_in	:	 799094840.3418435 m
# R_star	:	 1182690000.0001304 m
# R_in	:	 800479246.9725778 m
# R_star	:	 1182690017.6235847 m
# R_in	:	 800479249.2408129 m
# R_star	:	 1182689999.9999998 m
# R_in	:	 800479232.200821 m
# R_star	:	 1182690000.0 m
# R_in	:	 800479227.9408242 m
# R_star	:	 1182690000.0 m

# %%
res_lsq
# Out:
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [-2.044e-08 -2.044e-08 ... -5.337e-09 -5.329e-09]
#            x: [ 1.045e+00  5.220e-01  2.452e-06  1.700e+00]
#         cost: 2.5368322334978925e-14
#          jac: [[ 0.000e+00  2.524e+03  5.361e+08 -2.325e+03]
#                [ 0.000e+00  2.524e+03  5.361e+08 -2.325e+03]
#                ...
#                [ 0.000e+00  6.723e+02  1.428e+08 -3.825e+01]
#                [ 0.000e+00  6.714e+02  1.426e+08 -3.814e+01]]
#         grad: [ 0.000e+00 -6.355e-03 -1.350e+03  1.944e-03]
#   optimality: 1349.6644209944136
#  active_mask: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#         nfev: 32
#         njev: 13

# %%
print(f" B: {dum_cfg['b']} \n m: {dum_cfg['m']} \n m_dot: {dum_cfg['m_dot']} \n R: {dum_cfg['r_star']}")
# Out:
#  B: 1.0446310123905675 kG
#  m: 1.0379179688704715e+30 kg
#  m_dot: 1.545093596255276e+17 kg / s
#  R: 1182690000.0 m

# %%
print(dum_cfg['m']*dum_cfg['m_dot'])
# Out:
# 1.6036804071400486e+47 kg2 / s

# %%
y_mod = fun2(res_lsq.x, r_train, 0)
plt.plot(r_train, temp_train,label='training data')
plt.plot(r_train, y_mod,label='fit data')
plt.legend()
# Out:
# R_in	:	 800479226.5244577 m
# R_star	:	 1182690000.0001304 m

# %% [markdown]
# Creating a function to store bt settl arrays in the form of a dictionary. Retrieval will be in the form of key calls.
# Also this function should store the data and keep adding data for higher temperatures as it may be needed for later
# iterations.
# Test this and put into testing the visc disk flux generation

# %%
dr, t_max, d, r_in, r_sub = bf.generate_temp_arr(config=dict_config)
r_in, t_max
# Out:
# 1256915926.1027734 m
# 1182690000.0 m
# (<Quantity 1.25691593e+09 m>, 34)

# %%
def generate_bts_dict(config, d: dict, t_max, dr, r_in=None):
    """Generate the flux contributed by the viscously heated disk
    Parameters
    ----------
    config : dict
        dictionary containing system parameters
    d : dict
        dictionary produced by generate_temp_arr, having the radii and their
        corresponding temperatures reduced to the integer values
    t_max : int
        maximum temperature of the viscously heated disk, reduced to nearest int BT-Settl value
    dr : astropy.units.Quantity or None
        thickness of each annulus
    r_in : astropy.units.Quantity
        inner truncation radius, needed to estimate padding

    Returns
    ----------
    wavelength : astropy.units.Quantity
        wavelength array in units of Angstrom
    obs_viscous_disk_flux : astropy.units.Quantity
        observed flux from the viscous disk, in units of erg / (cm^2 s A)
    """
    dict_wavelength = {}
    dict_flux = {}
    for int_temp in range(t_max, 13, -1):
        # to store total flux contribution from annuli of this temperature
        
        radii = np.array([r for r, t in d.items() if t == int_temp])
        radii = radii * u.m
        radii = sorted(radii, reverse=True)

        if int_temp in range(14, 20):  # constrained by availability of BT-Settl models
            logg = 3.5
        else:
            logg = 1.5

        wavelength, flux = bf.read_bt_settl(config, int_temp, logg, r_in)
        print(f"Temp\t:\t{int_temp}\tLogg\t:\t{logg}\tlen\t:\t{len(wavelength)}")
        dict_wavelength[f"{int_temp}"] = wavelength
        dict_flux[f"{int_temp}"] = flux
    # print(dict_wavelength)
    return dict_wavelength, dict_flux

# %%
dict_wave, dict_flux = generate_bts_dict(dict_config, d, t_max, dr, r_in)
# Out:
# Temp	:	34	Logg	:	1.5	len	:	349284
# Temp	:	33	Logg	:	1.5	len	:	349300
# Temp	:	32	Logg	:	1.5	len	:	349329
# Temp	:	31	Logg	:	1.5	len	:	349344
# Temp	:	30	Logg	:	1.5	len	:	349370
# Temp	:	29	Logg	:	1.5	len	:	349393
# Temp	:	28	Logg	:	1.5	len	:	349411
# Temp	:	27	Logg	:	1.5	len	:	349450
# Temp	:	26	Logg	:	1.5	len	:	349506
# Temp	:	25	Logg	:	1.5	len	:	420000
# Temp	:	24	Logg	:	1.5	len	:	420000
# Temp	:	23	Logg	:	1.5	len	:	420000
# Temp	:	22	Logg	:	1.5	len	:	420000
# Temp	:	21	Logg	:	1.5	len	:	420000
# Temp	:	20	Logg	:	1.5	len	:	420000
# Temp	:	19	Logg	:	3.5	len	:	456102
# Temp	:	18	Logg	:	3.5	len	:	456102
# Temp	:	17	Logg	:	3.5	len	:	456102
# Temp	:	16	Logg	:	3.5	len	:	456102
# Temp	:	15	Logg	:	3.5	len	:	456102
# Temp	:	14	Logg	:	3.5	len	:	456102

# %%
## Here defined a new function which takes the dictionaries of flux and wavelengths stored
# and does faster computation for viscous disk part
# it also add newer temperature data into the dict if not present earlier

def generate_visc_flux(config, dict_wave, dict_flux, d: dict, t_max, dr, r_in=None):
    """Generate the flux contributed by the viscously heated disk
    Parameters
    ----------
    config : dict
        dictionary containing system parameters
    d : dict
        dictionary produced by generate_temp_arr, having the radii and their
        corresponding temperatures reduced to the integer values
    t_max : int
        maximum temperature of the viscously heated disk, reduced to nearest int BT-Settl value
    dr : astropy.units.Quantity or None
        thickness of each annulus
    r_in : astropy.units.Quantity
        inner truncation radius, needed to estimate padding

    Returns
    ----------
    wavelength : astropy.units.Quantity
        wavelength array in units of Angstrom
    obs_viscous_disk_flux : astropy.units.Quantity
        observed flux from the viscous disk, in units of erg / (cm^2 s A)
    """
    
    plot = config['plot']
    save = config['save']
    save_each = config['save_each']
    save_loc = config['save_loc']
    d_star = config['d_star']
    inclination = config['inclination']
    m = config['m']
    l_min = config['l_min']
    l_max = config['l_max']
    n_data = config['n_data']
    viscous_disk_flux = np.zeros(n_data) * (u.erg * u.m ** 2 / (u.cm ** 2 * u.s * u.AA))  # total number of data points

    for int_temp in range(t_max, 13, -1):
        # to store total flux contribution from annuli of this temperature
        temp_flux = np.zeros(n_data) * (u.erg / (u.s * u.AA))

        radii = np.array([r for r, t in d.items() if t == int_temp])
        radii = radii * u.m
        radii = sorted(radii, reverse=True)

        if int_temp in range(14, 20):  # constrained by availability of BT-Settl models
            logg = 3.5
        else:
            logg = 1.5
        
        # wavelength, flux = read_bt_settl(config, int_temp, logg, r_in)  
        if f"{int_temp}" in dict_wave:
            wavelength = dict_wave[f"{int_temp}"]
            # wavelength = t_arr   # comes because it is the independent fitting axis
            flux = dict_flux[f"{int_temp}"]
        else:
            print("Data array doesn't exist in dict\nAdding it!")
            wavelength, flux = bf.read_bt_settl(config, int_temp, logg, r_in)
            print(f"Temp\t:\t{int_temp}\tLogg\t:\t{logg}")
            dict_wave[f"{int_temp}"] = wavelength
            dict_flux[f"{int_temp}"] = flux
        
        for r in radii:
            if inclination.value == 0:
                x_throw, y_final = bf.logspace_reinterp(config, wavelength, flux)
            else:
                v_kep = np.sqrt(const.G * m / r)
                v_red = v_kep * np.sin(inclination) / const.c
                interp_samp, wavelength_new, flux_new = bf.interpolate_conv(config, wavelength, flux, 100, v_red)
                kernel = bf.generate_kernel(config, interp_samp, v_red)

                convolved_spectra = np.convolve(flux_new, kernel, mode="same")

                x_throw, y_final = bf.logspace_reinterp(config, wavelength_new, convolved_spectra)
                if save_each:
                    np.save(f'{save_loc}/radius_{r}_flux.npy', y_final.value)
            temp_flux += y_final * np.pi * (2 * r * dr + dr ** 2)
        viscous_disk_flux += temp_flux
        print("completed for temperature of", int_temp, "\nnumber of rings included:", len(radii))
        if save:
            np.save(f'{save_loc}/{int_temp}_flux.npy', temp_flux.value)
    wavelength = np.logspace(np.log10(l_min.value), np.log10(l_max.value), n_data) * u.AA
    obs_viscous_disk_flux = viscous_disk_flux * np.cos(inclination) / (np.pi * d_star ** 2)
    obs_viscous_disk_flux = obs_viscous_disk_flux.to(u.erg / (u.cm ** 2 * u.s * u.AA))
    if save:
        np.save(f'{save_loc}/disk_component.npy', obs_viscous_disk_flux.value)
    if plot:
        plt.plot(wavelength, obs_viscous_disk_flux)
        plt.xlabel("Wavelength in Angstrom ----->")
        plt.ylabel("Flux [erg / ($cm^{2}$ s angstrom)] ----->")
        plt.title("Viscous Disk SED")
        plt.show()

    return wavelength, obs_viscous_disk_flux

# %%
wavelength, obs_viscous_disk_flux = generate_visc_flux(dict_config, dict_wave, dict_flux, d, t_max, dr)
# Out:
# /home/arch/anaconda3/envs/yso/lib/python3.10/site-packages/astropy/units/quantity.py:620: RuntimeWarning: invalid value encountered in sqrt
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# completed for temperature of 34
# number of rings included: 40
# completed for temperature of 33
# number of rings included: 10
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 11
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 43
# completed for temperature of 14
# number of rings included: 25

# %%
plt.plot(wavelength, obs_viscous_disk_flux)
plt.yscale('log')

# %%
def gen_visc_flux_lsq(t,config, dict_wave, dict_flux, d: dict, t_max, dr, r_in=None):
    """Generate the flux contributed by the viscously heated disk
    Parameters
    ----------
    config : dict
        dictionary containing system parameters
    d : dict
        dictionary produced by generate_temp_arr, having the radii and their
        corresponding temperatures reduced to the integer values
    t_max : int
        maximum temperature of the viscously heated disk, reduced to nearest int BT-Settl value
    dr : astropy.units.Quantity or None
        thickness of each annulus
    r_in : astropy.units.Quantity
        inner truncation radius, needed to estimate padding

    Returns
    ----------
    wavelength : astropy.units.Quantity
        wavelength array in units of Angstrom
    obs_viscous_disk_flux : astropy.units.Quantity
        observed flux from the viscous disk, in units of erg / (cm^2 s A)
    """
    plot = config['plot']
    save = config['save']
    save_each = config['save_each']
    save_loc = config['save_loc']
    d_star = config['d_star']
    inclination = config['inclination']
    m = config['m']
    l_min = config['l_min']
    l_max = config['l_max']
    n_data = config['n_data']
    viscous_disk_flux = np.zeros(n_data) * (u.erg * u.m ** 2 / (u.cm ** 2 * u.s * u.AA))  # total number of data points

    for int_temp in range(t_max, 13, -1):
        # to store total flux contribution from annuli of this temperature
        temp_flux = np.zeros(n_data) * (u.erg / (u.s * u.AA))

        radii = np.array([r for r, t in d.items() if t == int_temp])
        radii = radii * u.m
        radii = sorted(radii, reverse=True)

        if int_temp in range(14, 20):  # constrained by availability of BT-Settl models
            logg = 3.5
        else:
            logg = 1.5
        
        # wavelength, flux = read_bt_settl(config, int_temp, logg, r_in)
        if f"{int_temp}" in dict_wave:
            wavelength = dict_wave[f"{int_temp}"]
            # wavelength = t_arr   # comes because it is the independent fitting axis
            flux = dict_flux[f"{int_temp}"]
        else:
            print("Data array doesn't exist in dict\nAdding it!")
            wavelength, flux = bf.read_bt_settl(config, int_temp, logg, r_in)
            print(f"Temp\t:\t{int_temp}\tLogg\t:\t{logg}")
            dict_wave[f"{int_temp}"] = wavelength
            dict_flux[f"{int_temp}"] = flux
        
        for r in radii:
            if inclination.value == 0:
                x_throw, y_final = bf.logspace_reinterp(config, wavelength, flux)
            else:
                v_kep = np.sqrt(const.G * m / r)
                v_red = v_kep * np.sin(inclination) / const.c
                interp_samp, wavelength_new, flux_new = bf.interpolate_conv(config, wavelength, flux, 100, v_red)
                kernel = bf.generate_kernel(config, interp_samp, v_red)

                convolved_spectra = np.convolve(flux_new, kernel, mode="same")

                x_throw, y_final = bf.logspace_reinterp(config, wavelength_new, convolved_spectra)
                if save_each:
                    np.save(f'{save_loc}/radius_{r}_flux.npy', y_final.value)
            temp_flux += y_final * np.pi * (2 * r * dr + dr ** 2)
        viscous_disk_flux += temp_flux
        print("completed for temperature of", int_temp, "\nnumber of rings included:", len(radii))
        if save:
            np.save(f'{save_loc}/{int_temp}_flux.npy', temp_flux.value)
    ## Here we have to fix the axis according to the input t
    # l_min = min(t)
    # l_max = max(t)
    # n_data = len(t)
    # print(l_min, l_max, n_data)
    wavelength = np.logspace(np.log10(l_min.value), np.log10(l_max.value), n_data) * u.AA
    obs_viscous_disk_flux = viscous_disk_flux * np.cos(inclination) / (np.pi * d_star ** 2)
    obs_viscous_disk_flux = obs_viscous_disk_flux.to(u.erg / (u.cm ** 2 * u.s * u.AA))
    if save:
        np.save(f'{save_loc}/disk_component.npy', obs_viscous_disk_flux.value)
    if plot:
        plt.plot(wavelength, obs_viscous_disk_flux)
        plt.xlabel("Wavelength in Angstrom ----->")
        plt.ylabel("Flux [erg / ($cm^{2}$ s angstrom)] ----->")
        plt.title("Viscous Disk SED")
        plt.show()

    return obs_viscous_disk_flux

# %%
dum_cfg = bf.config_read("config_file.cfg")

def fun_visc(x,t,y):
    """
    Error function for viscous disk flux fitting
    x[0] = m
    x[1] = m_dot
    x[2] = r_star
    x[3] = d_star
    x[4] = inclination
    x[5] = 
    Here the fitting is not so good because we are fixing the radius array, but in reality
    it also depends on the x vector parameters
    """
    # print(x)
    dum_cfg["m"] = x[0] * const.M_sun
    dum_cfg["m_dot"] = x[1] * const.M_sun/ (1 * u.year).to(u.s)
    # dum_cfg["r_star"] = x[3] * const.R_sun
    # dum_cfg["d_star"] = x[4]  * const.pc
    dum_cfg["inclination"] = x[2] * u.degree
    
    ## Below part is copeied from generate visc temp func with some changes
    dr, t_max, d, r_in, r_sub = bf.generate_temp_arr(dum_cfg)
    obs_viscous_disk_flux = gen_visc_flux_lsq(t,dum_cfg, dict_wave, dict_flux, d, t_max, dr)
    
    return (obs_viscous_disk_flux.value - y)/y

# %%
dum_cfg
# Out:
# {'b': <Quantity 1. kG>,
#  'm': <Quantity 1.39188691e+30 kg>,
#  'm_dot': <Quantity 2.52035626e+16 kg / s>,
#  'r_star': <Quantity 1.18269e+09 m>,
#  'log_g_star': 3.5,
#  'inclination': <Quantity 38. deg>,
#  'd_star': <Quantity 3.08567758e+17 m>,
#  't_star': <Quantity 4600. K>,
#  't_0': <Quantity 4600. K>,
#  'av': 10.0,
#  'rv': 3.1,
#  'l_0': <Quantity 3000. Angstrom>,
#  'l_l_slab': <Quantity 3000. Angstrom>,
#  'mag_comp': 'hslab',
#  't_slab': <Quantity 8500. K>,
#  'n_e': <Quantity 1.e+13 1 / cm3>,
#  'tau': 1.0,
#  'save': False,
#  'plot': False,
#  'save_grid_data': False,
#  'save_each': False,
#  'l_min': <Quantity 1250. Angstrom>,
#  'l_max': <Quantity 50000. Angstrom>,
#  'n_data': 420000,
#  'n_disk': 500,
#  'n_dust_disk': 2000,
#  'n_h_minus': 5000,
#  'n_h': 150,
#  'bt_settl_path': '/home/arch/yso/trial_downloads',
#  'save_loc': '/home/arch/yso/trial_25_03/save',
#  'h_grid_path': '/home/arch/yso/H_slab_data/GridHslab',
#  'h_min_grid_path': '/home/arch/yso/H_slab_data/GridH-slab'}

# %%
x0 = [1, 1e-6, 20]
res_lsq = least_squares(fun_visc, x0, args=(wavelength, obs_viscous_disk_flux.value),bounds = ((0.5,3e-7,18.),(1.05,2e-6,45.)))
res_lsq
# Out:
# 919348628.1519545 m
# 1182690000.0 m
# Data array doesn't exist in dict
# Adding it!
# Temp	:	50	Logg	:	1.5
# completed for temperature of 50
# number of rings included: 16
# Data array doesn't exist in dict
# Adding it!
# Temp	:	49	Logg	:	1.5
# completed for temperature of 49
# number of rings included: 7
# Data array doesn't exist in dict
# Adding it!
# Temp	:	48	Logg	:	1.5
# completed for temperature of 48
# number of rings included: 4
# Data array doesn't exist in dict
# Adding it!
# Temp	:	47	Logg	:	1.5
# completed for temperature of 47
# number of rings included: 4
# Data array doesn't exist in dict
# Adding it!
# Temp	:	46	Logg	:	1.5
# completed for temperature of 46
# number of rings included: 4
# Data array doesn't exist in dict
# Adding it!
# Temp	:	45	Logg	:	1.5
# completed for temperature of 45
# number of rings included: 3
# Data array doesn't exist in dict
# Adding it!
# Temp	:	44	Logg	:	1.5
# completed for temperature of 44
# number of rings included: 4
# Data array doesn't exist in dict
# Adding it!
# Temp	:	43	Logg	:	1.5
# completed for temperature of 43
# number of rings included: 4
# Data array doesn't exist in dict
# Adding it!
# Temp	:	42	Logg	:	1.5
# completed for temperature of 42
# number of rings included: 4
# Data array doesn't exist in dict
# Adding it!
# Temp	:	41	Logg	:	1.5
# completed for temperature of 41
# number of rings included: 5
# Data array doesn't exist in dict
# Adding it!
# Temp	:	40	Logg	:	1.5
# completed for temperature of 40
# number of rings included: 4
# Data array doesn't exist in dict
# Adding it!
# Temp	:	39	Logg	:	1.5
# completed for temperature of 39
# number of rings included: 5
# Data array doesn't exist in dict
# Adding it!
# Temp	:	38	Logg	:	1.5
# completed for temperature of 38
# number of rings included: 5
# Data array doesn't exist in dict
# Adding it!
# Temp	:	37	Logg	:	1.5
# completed for temperature of 37
# number of rings included: 5
# Data array doesn't exist in dict
# Adding it!
# Temp	:	36	Logg	:	1.5
# completed for temperature of 36
# number of rings included: 5
# Data array doesn't exist in dict
# Adding it!
# Temp	:	35	Logg	:	1.5
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 6
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 8
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 23
# 919348626.194903 m
# 1182690000.0 m
# completed for temperature of 50
# number of rings included: 16
# completed for temperature of 49
# number of rings included: 7
# completed for temperature of 48
# number of rings included: 4
# completed for temperature of 47
# number of rings included: 4
# completed for temperature of 46
# number of rings included: 4
# completed for temperature of 45
# number of rings included: 3
# completed for temperature of 44
# number of rings included: 4
# completed for temperature of 43
# number of rings included: 4
# completed for temperature of 42
# number of rings included: 4
# completed for temperature of 41
# number of rings included: 5
# completed for temperature of 40
# number of rings included: 4
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 5
# completed for temperature of 37
# number of rings included: 5
# completed for temperature of 36
# number of rings included: 5
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 6
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 8
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 23
# 915471598.5961919 m
# 1182690000.0 m
# completed for temperature of 50
# number of rings included: 18
# completed for temperature of 49
# number of rings included: 5
# completed for temperature of 48
# number of rings included: 4
# completed for temperature of 47
# number of rings included: 4
# completed for temperature of 46
# number of rings included: 4
# completed for temperature of 45
# number of rings included: 4
# completed for temperature of 44
# number of rings included: 4
# completed for temperature of 43
# number of rings included: 4
# completed for temperature of 42
# number of rings included: 4
# completed for temperature of 41
# number of rings included: 4
# completed for temperature of 40
# number of rings included: 4
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 5
# completed for temperature of 37
# number of rings included: 5
# completed for temperature of 36
# number of rings included: 6
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 6
# completed for temperature of 33
# number of rings included: 6
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 8
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 24
# 919348628.1519545 m
# 1182690000.0 m
# completed for temperature of 50
# number of rings included: 16
# completed for temperature of 49
# number of rings included: 7
# completed for temperature of 48
# number of rings included: 4
# completed for temperature of 47
# number of rings included: 4
# completed for temperature of 46
# number of rings included: 4
# completed for temperature of 45
# number of rings included: 3
# completed for temperature of 44
# number of rings included: 4
# completed for temperature of 43
# number of rings included: 4
# completed for temperature of 42
# number of rings included: 4
# completed for temperature of 41
# number of rings included: 5
# completed for temperature of 40
# number of rings included: 4
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 5
# completed for temperature of 37
# number of rings included: 5
# completed for temperature of 36
# number of rings included: 5
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 6
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 8
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 23
# 982898773.5259888 m
# 1182690000.0 m
# completed for temperature of 46
# number of rings included: 22
# completed for temperature of 45
# number of rings included: 6
# completed for temperature of 44
# number of rings included: 5
# completed for temperature of 43
# number of rings included: 4
# completed for temperature of 42
# number of rings included: 5
# completed for temperature of 41
# number of rings included: 5
# completed for temperature of 40
# number of rings included: 4
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 5
# completed for temperature of 37
# number of rings included: 6
# completed for temperature of 36
# number of rings included: 5
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 7
# completed for temperature of 33
# number of rings included: 6
# completed for temperature of 32
# number of rings included: 8
# completed for temperature of 31
# number of rings included: 7
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 23
# 982898771.1593634 m
# 1182690000.0 m
# completed for temperature of 46
# number of rings included: 22
# completed for temperature of 45
# number of rings included: 6
# completed for temperature of 44
# number of rings included: 5
# completed for temperature of 43
# number of rings included: 4
# completed for temperature of 42
# number of rings included: 5
# completed for temperature of 41
# number of rings included: 5
# completed for temperature of 40
# number of rings included: 4
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 5
# completed for temperature of 37
# number of rings included: 6
# completed for temperature of 36
# number of rings included: 5
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 7
# completed for temperature of 33
# number of rings included: 6
# completed for temperature of 32
# number of rings included: 8
# completed for temperature of 31
# number of rings included: 7
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 23
# 977982830.4270754 m
# 1182690000.0 m
# completed for temperature of 46
# number of rings included: 23
# completed for temperature of 45
# number of rings included: 6
# completed for temperature of 44
# number of rings included: 4
# completed for temperature of 43
# number of rings included: 5
# completed for temperature of 42
# number of rings included: 5
# completed for temperature of 41
# number of rings included: 4
# completed for temperature of 40
# number of rings included: 5
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 5
# completed for temperature of 37
# number of rings included: 5
# completed for temperature of 36
# number of rings included: 6
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 6
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 8
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 11
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 24
# 982898773.5259888 m
# 1182690000.0 m
# completed for temperature of 46
# number of rings included: 22
# completed for temperature of 45
# number of rings included: 6
# completed for temperature of 44
# number of rings included: 5
# completed for temperature of 43
# number of rings included: 4
# completed for temperature of 42
# number of rings included: 5
# completed for temperature of 41
# number of rings included: 5
# completed for temperature of 40
# number of rings included: 4
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 5
# completed for temperature of 37
# number of rings included: 6
# completed for temperature of 36
# number of rings included: 5
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 7
# completed for temperature of 33
# number of rings included: 6
# completed for temperature of 32
# number of rings included: 8
# completed for temperature of 31
# number of rings included: 7
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 23
# 1067873941.1925175 m
# 1182690000.0 m
# completed for temperature of 42
# number of rings included: 26
# completed for temperature of 41
# number of rings included: 7
# completed for temperature of 40
# number of rings included: 6
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 6
# completed for temperature of 37
# number of rings included: 6
# completed for temperature of 36
# number of rings included: 6
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 7
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 24
# 1067873938.2240592 m
# 1182690000.0 m
# completed for temperature of 42
# number of rings included: 26
# completed for temperature of 41
# number of rings included: 7
# completed for temperature of 40
# number of rings included: 6
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 6
# completed for temperature of 37
# number of rings included: 6
# completed for temperature of 36
# number of rings included: 6
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 7
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 24
# 1061247558.8161961 m
# 1182690000.0 m
# completed for temperature of 42
# number of rings included: 27
# completed for temperature of 41
# number of rings included: 7
# completed for temperature of 40
# number of rings included: 6
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 6
# completed for temperature of 37
# number of rings included: 6
# completed for temperature of 36
# number of rings included: 6
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 7
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 10
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 21
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 27
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 36
# completed for temperature of 15
# number of rings included: 43
# completed for temperature of 14
# number of rings included: 23
# 1067873941.1925175 m
# 1182690000.0 m
# completed for temperature of 42
# number of rings included: 26
# completed for temperature of 41
# number of rings included: 7
# completed for temperature of 40
# number of rings included: 6
# completed for temperature of 39
# number of rings included: 5
# completed for temperature of 38
# number of rings included: 6
# completed for temperature of 37
# number of rings included: 6
# completed for temperature of 36
# number of rings included: 6
# completed for temperature of 35
# number of rings included: 6
# completed for temperature of 34
# number of rings included: 7
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 7
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 9
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 12
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 17
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 31
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 24
# 1169255000.391015 m
# 1182690000.0 m
# completed for temperature of 38
# number of rings included: 31
# completed for temperature of 37
# number of rings included: 8
# completed for temperature of 36
# number of rings included: 8
# completed for temperature of 35
# number of rings included: 7
# completed for temperature of 34
# number of rings included: 8
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 8
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 25
# 1169254996.6187835 m
# 1182690000.0 m
# completed for temperature of 38
# number of rings included: 31
# completed for temperature of 37
# number of rings included: 8
# completed for temperature of 36
# number of rings included: 8
# completed for temperature of 35
# number of rings included: 7
# completed for temperature of 34
# number of rings included: 8
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 8
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 25
# 1160039174.7844803 m
# 1182690000.0 m
# completed for temperature of 38
# number of rings included: 33
# completed for temperature of 37
# number of rings included: 8
# completed for temperature of 36
# number of rings included: 7
# completed for temperature of 35
# number of rings included: 7
# completed for temperature of 34
# number of rings included: 8
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 8
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 14
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 24
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 43
# completed for temperature of 14
# number of rings included: 24
# 1169255000.391015 m
# 1182690000.0 m
# completed for temperature of 38
# number of rings included: 31
# completed for temperature of 37
# number of rings included: 8
# completed for temperature of 36
# number of rings included: 8
# completed for temperature of 35
# number of rings included: 7
# completed for temperature of 34
# number of rings included: 8
# completed for temperature of 33
# number of rings included: 7
# completed for temperature of 32
# number of rings included: 8
# completed for temperature of 31
# number of rings included: 8
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 15
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 19
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 42
# completed for temperature of 14
# number of rings included: 25
# 1255377895.1611245 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 33
# completed for temperature of 33
# number of rings included: 13
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 10
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 11
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 14
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 44
# completed for temperature of 14
# number of rings included: 24
# 1255377890.6556041 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 33
# completed for temperature of 33
# number of rings included: 13
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 10
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 11
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 14
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 44
# completed for temperature of 14
# number of rings included: 24
# 1243392848.8738008 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 39
# completed for temperature of 33
# number of rings included: 11
# completed for temperature of 32
# number of rings included: 9
# completed for temperature of 31
# number of rings included: 10
# completed for temperature of 30
# number of rings included: 9
# completed for temperature of 29
# number of rings included: 11
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# /home/arch/anaconda3/envs/yso/lib/python3.10/site-packages/astropy/units/quantity.py:620: RuntimeWarning: divide by zero encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 44
# completed for temperature of 14
# number of rings included: 24
# 1255377895.1611245 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 33
# completed for temperature of 33
# number of rings included: 13
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 10
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 11
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 12
# completed for temperature of 25
# number of rings included: 14
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 44
# completed for temperature of 14
# number of rings included: 24
# 1236817965.9519794 m
# 1182690000.0 m
# completed for temperature of 35
# number of rings included: 29
# completed for temperature of 34
# number of rings included: 13
# completed for temperature of 33
# number of rings included: 10
# completed for temperature of 32
# number of rings included: 9
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 11
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 33
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 44
# completed for temperature of 14
# number of rings included: 24
# 1236819459.2424166 m
# 1182690000.0 m
# completed for temperature of 35
# number of rings included: 29
# completed for temperature of 34
# number of rings included: 13
# completed for temperature of 33
# number of rings included: 10
# completed for temperature of 32
# number of rings included: 9
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 11
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 33
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 44
# completed for temperature of 14
# number of rings included: 24
# 1248752411.919823 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 37
# completed for temperature of 33
# number of rings included: 11
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 11
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 43
# completed for temperature of 14
# number of rings included: 25
# 1248752407.4380813 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 37
# completed for temperature of 33
# number of rings included: 11
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 11
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 43
# completed for temperature of 14
# number of rings included: 25
# 1237044809.2337344 m
# 1182690000.0 m
# completed for temperature of 35
# number of rings included: 29
# completed for temperature of 34
# number of rings included: 13
# completed for temperature of 33
# number of rings included: 10
# completed for temperature of 32
# number of rings included: 9
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 10
# completed for temperature of 28
# number of rings included: 11
# completed for temperature of 27
# number of rings included: 11
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 28
# completed for temperature of 17
# number of rings included: 33
# completed for temperature of 16
# number of rings included: 37
# completed for temperature of 15
# number of rings included: 44
# completed for temperature of 14
# number of rings included: 24
# 1248752411.919823 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 37
# completed for temperature of 33
# number of rings included: 11
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 11
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 43
# completed for temperature of 14
# number of rings included: 25
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [-1.006e-01 -1.001e-01 ... -5.028e-02 -5.192e-02]
#            x: [ 5.931e-01  4.446e-07  3.933e+01]
#         cost: 1676.0976473138123
#          jac: [[ 5.736e-01  6.987e+08 -1.286e-02]
#                [ 5.745e-01  6.960e+08 -1.287e-02]
#                ...
#                [ 1.753e-01  2.273e+06 -3.507e-02]
#                [ 2.286e-01  2.264e+06 -3.364e-02]]
#         grad: [-1.554e+04 -4.155e+12  7.476e+02]
#   optimality: 6462986.385536497
#  active_mask: [0 0 0]
#         nfev: 8
#         njev: 6

# %%
res_lsq.x
# Out:
# array([5.93132329e-01, 4.44567617e-07, 3.93291528e+01])

# %%
dum_cfg['m'] = res_lsq.x[0] * const.M_sun
dum_cfg['m_dot'] = res_lsq.x[1] * const.M_sun / (1*u.year).to(u.s)
dum_cfg['inclination'] = res_lsq.x[2] * u.degree

# %%
dr, t_max, d, r_in, r_sub = bf.generate_temp_arr(config=dum_cfg)
y_mod_visc = gen_visc_flux_lsq(0.,dum_cfg, dict_wave, dict_flux, d, t_max, dr)
plt.plot(wavelength, obs_viscous_disk_flux)
plt.plot(wavelength, y_mod_visc)
# Out:
# 1248752411.919823 m
# 1182690000.0 m
# completed for temperature of 34
# number of rings included: 37
# completed for temperature of 33
# number of rings included: 11
# completed for temperature of 32
# number of rings included: 10
# completed for temperature of 31
# number of rings included: 9
# completed for temperature of 30
# number of rings included: 10
# completed for temperature of 29
# number of rings included: 11
# completed for temperature of 28
# number of rings included: 10
# completed for temperature of 27
# number of rings included: 12
# completed for temperature of 26
# number of rings included: 13
# completed for temperature of 25
# number of rings included: 13
# completed for temperature of 24
# number of rings included: 15
# completed for temperature of 23
# number of rings included: 16
# completed for temperature of 22
# number of rings included: 18
# completed for temperature of 21
# number of rings included: 20
# completed for temperature of 20
# number of rings included: 22
# completed for temperature of 19
# number of rings included: 25
# completed for temperature of 18
# number of rings included: 29
# completed for temperature of 17
# number of rings included: 32
# completed for temperature of 16
# number of rings included: 38
# completed for temperature of 15
# number of rings included: 43
# completed for temperature of 14
# number of rings included: 25

# %%
plt.plot(wavelength, obs_viscous_disk_flux,label='train')
plt.plot(wavelength, y_mod_visc, label = 'fit')
plt.xlim(9200,9800)
plt.ylim(2e-11,6e-11)
plt.legend()
plt.yscale('log')

# %%
dum_cfg
# Out:
# {'b': <Quantity 1. kG>,
#  'm': <Quantity 1.17939018e+30 kg>,
#  'm_dot': <Quantity 2.80117195e+16 kg / s>,
#  'r_star': <Quantity 1.18269e+09 m>,
#  'log_g_star': 3.5,
#  'inclination': <Quantity 39.32915341 deg>,
#  'd_star': <Quantity 3.08567758e+17 m>,
#  't_star': <Quantity 4600. K>,
#  't_0': <Quantity 4600. K>,
#  'av': 10.0,
#  'rv': 3.1,
#  'l_0': <Quantity 3000. Angstrom>,
#  'l_l_slab': <Quantity 3000. Angstrom>,
#  'mag_comp': 'hslab',
#  't_slab': <Quantity 8500. K>,
#  'n_e': <Quantity 1.e+13 1 / cm3>,
#  'tau': 1.0,
#  'save': False,
#  'plot': False,
#  'save_grid_data': False,
#  'save_each': False,
#  'l_min': <Quantity 1250. Angstrom>,
#  'l_max': <Quantity 50000. Angstrom>,
#  'n_data': 420000,
#  'n_disk': 500,
#  'n_dust_disk': 2000,
#  'n_h_minus': 5000,
#  'n_h': 150,
#  'bt_settl_path': '/home/arch/yso/trial_downloads',
#  'save_loc': '/home/arch/yso/trial_25_03/save',
#  'h_grid_path': '/home/arch/yso/H_slab_data/GridHslab',
#  'h_min_grid_path': '/home/arch/yso/H_slab_data/GridH-slab'}

# %%
dict_config
# Out:
# {'b': <Quantity 1. kG>,
#  'm': <Quantity 1.98840987e+30 kg>,
#  'm_dot': <Quantity 2.52035626e+16 kg / s>,
#  'r_star': <Quantity 1.18269e+09 m>,
#  'log_g_star': 3.5,
#  'inclination': <Quantity 38. deg>,
#  'd_star': <Quantity 3.08567758e+17 m>,
#  't_star': <Quantity 4600. K>,
#  't_0': <Quantity 4600. K>,
#  'av': 10.0,
#  'rv': 3.1,
#  'l_0': <Quantity 3000. Angstrom>,
#  'l_l_slab': <Quantity 3000. Angstrom>,
#  'mag_comp': 'hslab',
#  't_slab': <Quantity 8500. K>,
#  'n_e': <Quantity 1.e+13 1 / cm3>,
#  'tau': 1.0,
#  'save': False,
#  'plot': False,
#  'save_grid_data': False,
#  'save_each': False,
#  'l_min': <Quantity 1250. Angstrom>,
#  'l_max': <Quantity 50000. Angstrom>,
#  'n_data': 420000,
#  'n_disk': 500,
#  'n_dust_disk': 2000,
#  'n_h_minus': 5000,
#  'n_h': 150,
#  'bt_settl_path': '/home/arch/yso/trial_downloads',
#  'save_loc': '/home/arch/yso/trial_25_03/save',
#  'h_grid_path': '/home/arch/yso/H_slab_data/GridHslab',
#  'h_min_grid_path': '/home/arch/yso/H_slab_data/GridH-slab'}

# %%
d
# Out:
# {1194475861.3142483: 39,
#  1216607167.276387: 39,
#  1238738473.2385254: 39,
#  1260869779.200664: 39,
#  1283001085.1628027: 39,
#  1305132391.124941: 39,
#  1327263697.0870798: 39,
#  1349395003.0492182: 39,
#  1371526309.0113568: 39,
#  1393657614.9734955: 39,
#  1415788920.935634: 39,
#  1437920226.8977726: 39,
#  1460051532.859911: 39,
#  1482182838.8220496: 39,
#  1504314144.7841883: 39,
#  1526445450.746327: 39,
#  1548576756.7084653: 39,
#  1570708062.6706038: 39,
#  1592839368.6327424: 39,
#  1614970674.594881: 39,
#  1637101980.5570197: 39,
#  1659233286.5191581: 39,
#  1681364592.4812968: 39,
#  1703495898.4434352: 39,
#  1725627204.4055738: 39,
#  1747758510.3677125: 39,
#  1769889816.329851: 39,
#  1792021122.2919896: 39,
#  1814152428.254128: 39,
#  1836283734.2162666: 39,
#  1858415040.1784053: 38,
#  1880546346.140544: 38,
#  1902677652.1026824: 38,
#  1924808958.0648208: 38,
#  1946940264.0269594: 38,
#  1969071569.989098: 38,
#  1991202875.9512367: 38,
#  2013334181.9133751: 38,
#  2035465487.8755138: 37,
#  2057596793.8376522: 37,
#  2079728099.7997909: 37,
#  2101859405.7619295: 37,
#  2123990711.724068: 37,
#  2146122017.6862066: 37,
#  2168253323.648345: 37,
#  2190384629.6104836: 36,
#  2212515935.5726223: 36,
#  2234647241.534761: 36,
#  2256778547.4968996: 36,
#  2278909853.459038: 36,
#  2301041159.4211764: 36,
#  2323172465.383315: 36,
#  2345303771.3454533: 35,
#  2367435077.3075924: 35,
#  2389566383.2697306: 35,
#  2411697689.231869: 35,
#  2433828995.194008: 35,
#  2455960301.1561465: 35,
#  2478091607.118285: 34,
#  2500222913.0804234: 34,
#  2522354219.0425625: 34,
#  2544485525.0047007: 34,
#  2566616830.9668393: 34,
#  2588748136.928978: 34,
#  2610879442.891116: 34,
#  2633010748.8532553: 33,
#  2655142054.8153934: 33,
#  2677273360.777532: 33,
#  2699404666.7396708: 33,
#  2721535972.701809: 33,
#  2743667278.663948: 33,
#  2765798584.626086: 33,
#  2787929890.588225: 33,
#  2810061196.5503635: 32,
#  2832192502.5125017: 32,
#  2854323808.474641: 32,
#  2876455114.436779: 32,
#  2898586420.3989177: 32,
#  2920717726.3610563: 32,
#  2942849032.3231945: 32,
#  2964980338.2853336: 32,
#  2987111644.247472: 31,
#  3009242950.2096105: 31,
#  3031374256.171749: 31,
#  3053505562.1338873: 31,
#  3075636868.0960264: 31,
#  3097768174.0581646: 31,
#  3119899480.0203032: 31,
#  3142030785.982442: 31,
#  3164162091.9445806: 30,
#  3186293397.906719: 30,
#  3208424703.8688574: 30,
#  3230556009.8309965: 30,
#  3252687315.7931347: 30,
#  3274818621.7552733: 30,
#  3296949927.717412: 30,
#  3319081233.67955: 30,
#  3341212539.6416893: 30,
#  3363343845.6038275: 29,
#  3385475151.5659657: 29,
#  3407606457.528105: 29,
#  3429737763.490243: 29,
#  3451869069.452382: 29,
#  3474000375.4145203: 29,
#  3496131681.3766584: 29,
#  3518262987.3387976: 29,
#  3540394293.3009357: 29,
#  3562525599.263075: 28,
#  3584656905.225213: 28,
#  3606788211.187352: 28,
#  3628919517.1494904: 28,
#  3651050823.1116285: 28,
#  3673182129.0737677: 28,
#  3695313435.035906: 28,
#  3717444740.998045: 28,
#  3739576046.960183: 28,
#  3761707352.9223213: 28,
#  3783838658.8844604: 27,
#  3805969964.8465986: 27,
#  3828101270.8087378: 27,
#  3850232576.770876: 27,
#  3872363882.733014: 27,
#  3894495188.695153: 27,
#  3916626494.6572914: 27,
#  3938757800.6194305: 27,
#  3960889106.5815687: 27,
#  3983020412.543707: 27,
#  4005151718.505846: 27,
#  4027283024.467984: 26,
#  4049414330.4301233: 26,
#  4071545636.3922615: 26,
#  4093676942.3543997: 26,
#  4115808248.316539: 26,
#  4137939554.278677: 26,
#  4160070860.240816: 26,
#  4182202166.2029543: 26,
#  4204333472.1650925: 26,
#  4226464778.1272316: 26,
#  4248596084.08937: 26,
#  4270727390.051509: 26,
#  4292858696.013647: 25,
#  4314990001.975786: 25,
#  4337121307.937924: 25,
#  4359252613.900063: 25,
#  4381383919.862202: 25,
#  4403515225.82434: 25,
#  4425646531.786479: 25,
#  4447777837.748617: 25,
#  4469909143.710755: 25,
#  4492040449.6728945: 25,
#  4514171755.635033: 25,
#  4536303061.597172: 25,
#  4558434367.55931: 25,
#  4580565673.521448: 24,
#  4602696979.483587: 24,
#  4624828285.445725: 24,
#  4646959591.407865: 24,
#  4669090897.370003: 24,
#  4691222203.332141: 24,
#  4713353509.29428: 24,
#  4735484815.256418: 24,
#  4757616121.218557: 24,
#  4779747427.180696: 24,
#  4801878733.142834: 24,
#  4824010039.104973: 24,
#  4846141345.067111: 24,
#  4868272651.02925: 24,
#  4890403956.991388: 23,
#  4912535262.9535265: 23,
#  4934666568.915666: 23,
#  4956797874.877804: 23,
#  4978929180.839943: 23,
#  5001060486.802081: 23,
#  5023191792.76422: 23,
#  5045323098.726358: 23,
#  5067454404.688497: 23,
#  5089585710.650636: 23,
#  5111717016.612774: 23,
#  5133848322.574913: 23,
#  5155979628.537051: 23,
#  5178110934.499189: 23,
#  5200242240.4613285: 23,
#  5222373546.423467: 23,
#  5244504852.385606: 22,
#  5266636158.347744: 22,
#  5288767464.309882: 22,
#  5310898770.272021: 22,
#  5333030076.234159: 22,
#  5355161382.196299: 22,
#  5377292688.158437: 22,
#  5399423994.120575: 22,
#  5421555300.082714: 22,
#  5443686606.044852: 22,
#  5465817912.006991: 22,
#  5487949217.96913: 22,
#  5510080523.931268: 22,
#  5532211829.893407: 22,
#  5554343135.855545: 22,
#  5576474441.817683: 22,
#  5598605747.779822: 22,
#  5620737053.741961: 22,
#  5642868359.7041: 21,
#  5664999665.666238: 21,
#  5687130971.628376: 21,
#  5709262277.590515: 21,
#  5731393583.552653: 21,
#  5753524889.514792: 21,
#  5775656195.476931: 21,
#  5797787501.439069: 21,
#  5819918807.401208: 21,
#  5842050113.363346: 21,
#  5864181419.325485: 21,
#  5886312725.287623: 21,
#  5908444031.249763: 21,
#  5930575337.211901: 21,
#  5952706643.174039: 21,
#  5974837949.136178: 21,
#  5996969255.098316: 21,
#  6019100561.060455: 21,
#  6041231867.0225935: 21,
#  6063363172.984732: 20,
#  6085494478.946871: 20,
#  6107625784.909009: 20,
#  6129757090.871148: 20,
#  6151888396.833286: 20,
#  6174019702.795424: 20,
#  6196151008.757564: 20,
#  6218282314.719702: 20,
#  6240413620.681841: 20,
#  6262544926.643979: 20,
#  6284676232.606117: 20,
#  6306807538.568256: 20,
#  6328938844.530395: 20,
#  6351070150.492534: 20,
#  6373201456.454672: 20,
#  6395332762.41681: 20,
#  6417464068.378949: 20,
#  6439595374.341087: 20,
#  6461726680.303226: 20,
#  6483857986.265365: 20,
#  6505989292.227504: 20,
#  6528120598.189642: 20,
#  6550251904.15178: 19,
#  6572383210.113919: 19,
#  6594514516.076057: 19,
#  6616645822.038197: 19,
#  6638777128.000335: 19,
#  6660908433.962473: 19,
#  6683039739.924612: 19,
#  6705171045.88675: 19,
#  6727302351.848889: 19,
#  6749433657.811028: 19,
#  6771564963.773166: 19,
#  6793696269.735305: 19,
#  6815827575.697443: 19,
#  6837958881.659582: 19,
#  6860090187.62172: 19,
#  6882221493.5838585: 19,
#  6904352799.545998: 19,
#  6926484105.508136: 19,
#  6948615411.470275: 19,
#  6970746717.432413: 19,
#  6992878023.394551: 19,
#  7015009329.35669: 19,
#  7037140635.318829: 19,
#  7059271941.280968: 19,
#  7081403247.243106: 18,
#  7103534553.205244: 18,
#  7125665859.167383: 18,
#  7147797165.129521: 18,
#  7169928471.0916605: 18,
#  7192059777.053799: 18,
#  7214191083.015937: 18,
#  7236322388.978076: 18,
#  7258453694.940214: 18,
#  7280585000.902353: 18,
#  7302716306.864491: 18,
#  7324847612.826631: 18,
#  7346978918.788769: 18,
#  7369110224.750907: 18,
#  7391241530.713046: 18,
#  7413372836.675184: 18,
#  7435504142.637323: 18,
#  7457635448.599462: 18,
#  7479766754.5616: 18,
#  7501898060.523739: 18,
#  7524029366.485877: 18,
#  7546160672.448016: 18,
#  7568291978.410154: 18,
#  7590423284.3722925: 18,
#  7612554590.334432: 18,
#  7634685896.29657: 18,
#  7656817202.258709: 18,
#  7678948508.220847: 18,
#  7701079814.182985: 17,
#  7723211120.145124: 17,
#  7745342426.107263: 17,
#  7767473732.069402: 17,
#  7789605038.03154: 17,
#  7811736343.993678: 17,
#  7833867649.955817: 17,
#  7855998955.917955: 17,
#  7878130261.880095: 17,
#  7900261567.842233: 17,
#  7922392873.804372: 17,
#  7944524179.76651: 17,
#  7966655485.728648: 17,
#  7988786791.690787: 17,
#  8010918097.6529255: 17,
#  8033049403.615065: 17,
#  8055180709.577203: 17,
#  8077312015.539341: 17,
#  8099443321.50148: 17,
#  8121574627.463618: 17,
#  8143705933.425757: 17,
#  8165837239.387896: 17,
#  8187968545.350034: 17,
#  8210099851.312173: 17,
#  8232231157.274311: 17,
#  8254362463.23645: 17,
#  8276493769.198588: 17,
#  8298625075.160727: 17,
#  8320756381.122866: 17,
#  8342887687.085004: 17,
#  8365018993.047143: 17,
#  8387150299.009281: 17,
#  8409281604.971419: 16,
#  8431412910.933558: 16,
#  8453544216.895697: 16,
#  8475675522.857836: 16,
#  8497806828.819974: 16,
#  8519938134.782112: 16,
#  8542069440.744251: 16,
#  8564200746.706389: 16,
#  8586332052.668529: 16,
#  8608463358.630667: 16,
#  8630594664.592806: 16,
#  8652725970.554945: 16,
#  8674857276.517082: 16,
#  8696988582.479221: 16,
#  8719119888.44136: 16,
#  8741251194.4035: 16,
#  8763382500.365637: 16,
#  8785513806.327776: 16,
#  8807645112.289915: 16,
#  8829776418.252052: 16,
#  8851907724.214191: 16,
#  8874039030.17633: 16,
#  8896170336.138468: 16,
#  8918301642.100607: 16,
#  8940432948.062746: 16,
#  8962564254.024885: 16,
#  8984695559.987022: 16,
#  9006826865.949162: 16,
#  9028958171.9113: 16,
#  9051089477.873438: 16,
#  9073220783.835577: 16,
#  9095352089.797716: 16,
#  9117483395.759853: 16,
#  9139614701.721992: 16,
#  9161746007.684132: 16,
#  9183877313.64627: 16,
#  9206008619.608408: 16,
#  9228139925.570547: 15,
#  9250271231.532686: 15,
#  9272402537.494823: 15,
#  9294533843.456963: 15,
#  9316665149.419102: 15,
#  9338796455.38124: 15,
#  9360927761.343378: 15,
#  9383059067.305517: 15,
#  9405190373.267656: 15,
#  9427321679.229794: 15,
#  9449452985.191933: 15,
#  9471584291.154072: 15,
#  9493715597.116209: 15,
#  9515846903.078348: 15,
#  9537978209.040487: 15,
#  9560109515.002626: 15,
#  9582240820.964764: 15,
#  9604372126.926903: 15,
#  9626503432.889042: 15,
#  9648634738.85118: 15,
#  9670766044.813318: 15,
#  9692897350.775457: 15,
#  9715028656.737595: 15,
#  9737159962.699734: 15,
#  9759291268.661873: 15,
#  9781422574.624012: 15,
#  9803553880.586151: 15,
#  9825685186.548288: 15,
#  9847816492.510427: 15,
#  9869947798.472567: 15,
#  9892079104.434704: 15,
#  9914210410.396843: 15,
#  9936341716.358982: 15,
#  9958473022.32112: 15,
#  9980604328.283258: 15,
#  10002735634.245398: 15,
#  10024866940.207537: 15,
#  10046998246.169674: 15,
#  10069129552.131813: 15,
#  10091260858.093952: 15,
#  10113392164.05609: 15,
#  10135523470.018229: 15,
#  10157654775.980368: 14,
#  10179786081.942505: 14,
#  10201917387.904644: 14,
#  10224048693.866783: 14,
#  10246179999.828922: 14,
#  10268311305.79106: 14,
#  10290442611.753199: 14,
#  10312573917.715338: 14,
#  10334705223.677475: 14,
#  10356836529.639614: 14,
#  10378967835.601753: 14,
#  10401099141.56389: 14,
#  10423230447.52603: 14,
#  10445361753.488169: 14,
#  10467493059.450308: 14,
#  10489624365.412445: 14,
#  10511755671.374584: 14,
#  10533886977.336723: 14,
#  10556018283.29886: 14,
#  10578149589.261: 14,
#  10600280895.223139: 14,
#  10622412201.185278: 14,
#  10644543507.147415: 14,
#  10666674813.109554: 14}
